# %%
# !pip install networkx==2.6.1
# !pip install WordCloud
# Out:
# Collecting networkx==2.6.1
#   Downloading networkx-2.6.1-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1 in c:\users\user\anaconda3\lib\site-packages (from networkx==2.6.1) (1.4.3)
# Requirement already satisfied: scipy!=1.6.1,>=1.5 in c:\users\user\anaconda3\lib\site-packages (from networkx==2.6.1) (1.7.3)
# Requirement already satisfied: numpy>=1.19 in c:\users\user\anaconda3\lib\site-packages (from networkx==2.6.1) (1.21.5)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\user\anaconda3\lib\site-packages (from networkx==2.6.1) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.1) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.1->networkx==2.6.1) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->networkx==2.6.1) (1.16.0)
# Installing collected packages: networkx
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.7.1
#     Uninstalling networkx-2.7.1:
#       Successfully uninstalled networkx-2.7.1
# Successfully installed networkx-2.6.1
# WARNING: The candidate selected for download or install is a yanked version: 'networkx' candidate (version 2.6.1 at https://files.pythonhosted.org/packages/5d/ca/a59802a56162889597dd787cff359b33bbe6c3a6f3313a546df35018be62/networkx-2.6.1-py3-none-any.whl#sha256=aa21cd7c7e0696672885866b2736a32bfd4bd20996ab99fc6142edf9357d3241 (from https://pypi.org/simple/networkx/) (requires-python:>=3.7))
# Reason for being yanked: Need to resolve: https://github.com/networkx/networkx/pull/4967
# Collecting WordCloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
#      -------------------------------------- 153.1/153.1 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from WordCloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from WordCloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from WordCloud) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->WordCloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->WordCloud) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->WordCloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->WordCloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.8.2.2

# %%
# !pip install konlpy
import konlpy.tag
from konlpy.tag import *

okt = Okt()
import re
import networkx as nx
import pandas as pd

from collections import Counter

df = pd.read_csv('final_file.csv', encoding = 'cp949')
minwon_contents = df.get('민원내용')
minwon_date = df.get('민원등록일시')
# Out:
# Requirement already satisfied: konlpy in c:\users\user\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (4.8.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.4.0)

# %%
stopwords = pd.read_csv('stopwords.csv',encoding= 'cp949')
stop_words_list = [i for i in stopwords['pattern']]

len(stop_words_list)
# Out:
# 861

# %%
from re import match
nouns = []
for sent in minwon_contents : 
    for noun in okt.nouns(sent) :
        if len(str(noun)) >= 2 and not(match('^[0-9]', noun)) :
            nouns.append(noun)
nouns[:1]
# Out:
# ['불법']

# %%
len(nouns)
# Out:
# 575837

# %%
nouns2 = []
for noun in nouns:
    if str(noun) not in stop_words_list:
        nouns2.append(noun)

# %%
len(nouns2)
# Out:
# 341211

# %%
nouns2[:5]
# Out:
# ['불법', '정차', '불법', '주차', '상세']

# %%
from collections import Counter
num = 20
nouns_counter = Counter(nouns2)
minwon_top_nouns = dict(nouns_counter.most_common(num))
minwon_top_nouns
# Out:
# {'불편': 16036,
#  '촬영': 11525,
#  '원단': 10292,
#  '생활': 9375,
#  '저장': 7371,
#  '기능': 7077,
#  '개선': 6759,
#  '한국': 6612,
#  '개발': 6603,
#  '정책': 6566,
#  '제도': 6554,
#  '용법': 6547,
#  '역정보': 6547,
#  '불법': 6388,
#  '주차': 6207,
#  '안내': 4985,
#  '정보': 4951,
#  '시스템': 4689,
#  '유지관리': 4660,
#  '사진촬영': 4310}

# %%
from wordcloud import WordCloud
wc = WordCloud(font_path='C:/Windows/Fonts/gulim.ttc', \
background_color="white", \
width=1000, \
height=1000, \
max_words=100, \
max_font_size=300)

wc.generate_from_frequencies(dict(minwon_top_nouns))
wc.to_file("wordcloud_a.jpg")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
wc2 = WordCloud(font_path='C:/Windows/Fonts/gulim.ttc', \
                background_color='white',\
                max_font_size=400, \
                colormap='seismic').generate_from_frequencies(dict(minwon_top_nouns))
plt.figure(figsize=(10,8))
plt.imshow(wc2)
plt.axis('off')

plt.show()
wc2.to_file("wordcloud_b.jpg")

# %%
minwon_word2id = {w: i for i, w in enumerate(minwon_top_nouns.keys())}
minwon_word2id
# Out:
# {'불편': 0,
#  '촬영': 1,
#  '원단': 2,
#  '생활': 3,
#  '저장': 4,
#  '기능': 5,
#  '개선': 6,
#  '한국': 7,
#  '개발': 8,
#  '정책': 9,
#  '제도': 10,
#  '용법': 11,
#  '역정보': 12,
#  '불법': 13,
#  '주차': 14,
#  '안내': 15,
#  '정보': 16,
#  '시스템': 17,
#  '유지관리': 18,
#  '사진촬영': 19}

# %%
minwon_id2word = {i: w for i, w in enumerate(minwon_top_nouns.keys())}
minwon_id2word
# Out:
# {0: '불편',
#  1: '촬영',
#  2: '원단',
#  3: '생활',
#  4: '저장',
#  5: '기능',
#  6: '개선',
#  7: '한국',
#  8: '개발',
#  9: '정책',
#  10: '제도',
#  11: '용법',
#  12: '역정보',
#  13: '불법',
#  14: '주차',
#  15: '안내',
#  16: '정보',
#  17: '시스템',
#  18: '유지관리',
#  19: '사진촬영'}

# %%
minwon_list = [i for i in minwon_contents]
minwon_list_nouns = []
for a in minwon_list:
    list_nouns = okt.nouns(a)
    minwon_list_nouns.append(list_nouns)
minwon_list_nouns[:1]
# Out:
# [['불법',
#   '정차',
#   '신고',
#   '불법',
#   '주차',
#   '상세',
#   '위치',
#   '설명',
#   '삼계동',
#   '푸르지오',
#   '차',
#   '경상남도',
#   '김해시',
#   '삼계동',
#   '부근',
#   '사진촬영',
#   '시간',
#   '안내',
#   '행정',
#   '공간',
#   '정보',
#   '체계',
#   '유지',
#   '보수',
#   '사업',
#   '단',
#   '앱',
#   '구동',
#   '중',
#   '바로',
#   '촬영',
#   '첨부',
#   '사진',
#   '신고',
#   '갤러리',
#   '첨부',
#   '사진',
#   '갤러리',
#   '첨부',
#   '사진',
#   '앱',
#   '실행',
#   '시',
#   '촬영',
#   '사진',
#   '갤러리',
#   '저장',
#   '사진',
#   '첨부',
#   '것',
#   '촬영',
#   '일시',
#   '보장',
#   '수',
#   '참고',
#   '생활',
#   '불편',
#   '스마트폰',
#   '신고',
#   '기능',
#   '관련',
#   '문의',
#   '전화',
#   '생활',
#   '불편',
#   '스마트폰',
#   '신고',
#   '기능',
#   '관련',
#   '문의',
#   '전화']]

# %%
import numpy as np
minwon_adjMatrix = np.zeros((num,num), int)
for sentence in minwon_list_nouns:
    for wi, i in minwon_word2id.items():
        if wi in sentence:
            for wj, j in minwon_word2id.items():
                if i != j and wj in sentence:
                    minwon_adjMatrix[i][j] += 1
minwon_adjMatrix
# Out:
#         4249, 4249, 3545, 2547, 4275, 4275, 4275,    0, 4088],
#        [4301, 4304, 4062, 4301, 3625, 4301, 4034, 4067, 4064, 4062, 4062,
#         4062, 4062, 3646, 2614, 4301, 4301, 4090, 4088,    0]])

# %%
minwon_network = nx.from_numpy_matrix(minwon_adjMatrix)
list(minwon_network.adjacency())
# Out:
# [(0,
#   {1: {'weight': 4511},
#    2: {'weight': 4430},
#    3: {'weight': 4713},
#    4: {'weight': 3770},
#    5: {'weight': 4687},
#    6: {'weight': 4422},
#    7: {'weight': 4435},
#    8: {'weight': 4435},
#    9: {'weight': 4432},
#    10: {'weight': 4431},
#    11: {'weight': 4430},
#    12: {'weight': 4430},
#    13: {'weight': 3853},
#    14: {'weight': 2763},
#    15: {'weight': 4498},
#    16: {'weight': 4497},
#    17: {'weight': 4279},
#    18: {'weight': 4275},
#    19: {'weight': 4301}}),
#  (1,
#   {0: {'weight': 4511},
#    2: {'weight': 4262},
#    3: {'weight': 4510},
#    4: {'weight': 3770},
#    5: {'weight': 4508},
#    6: {'weight': 4233},
#    7: {'weight': 4267},
#    8: {'weight': 4262},
#    9: {'weight': 4262},
#    10: {'weight': 4263},
#    11: {'weight': 4262},
#    12: {'weight': 4262},
#    13: {'weight': 3744},
#    14: {'weight': 2660},
#    15: {'weight': 4498},
#    16: {'weight': 4495},
#    17: {'weight': 4277},
#    18: {'weight': 4275},
#    19: {'weight': 4304}}),
#  (2,
#   {0: {'weight': 4430},
#    1: {'weight': 4262},
#    3: {'weight': 4430},
#    4: {'weight': 3596},
#    5: {'weight': 4430},
#    6: {'weight': 4397},
#    7: {'weight': 4430},
#    8: {'weight': 4430},
#    9: {'weight': 4430},
#    10: {'weight': 4430},
#    11: {'weight': 4430},
#    12: {'weight': 4430},
#    13: {'weight': 3590},
#    14: {'weight': 2580},
#    15: {'weight': 4250},
#    16: {'weight': 4249},
#    17: {'weight': 4249},
#    18: {'weight': 4249},
#    19: {'weight': 4062}}),
#  (3,
#   {0: {'weight': 4713},
#    1: {'weight': 4510},
#    2: {'weight': 4430},
#    4: {'weight': 3773},
#    5: {'weight': 4684},
#    6: {'weight': 4416},
#    7: {'weight': 4435},
#    8: {'weight': 4430},
#    9: {'weight': 4431},
#    10: {'weight': 4431},
#    11: {'weight': 4430},
#    12: {'weight': 4430},
#    13: {'weight': 3819},
#    14: {'weight': 2718},
#    15: {'weight': 4502},
#    16: {'weight': 4499},
#    17: {'weight': 4277},
#    18: {'weight': 4275},
#    19: {'weight': 4301}}),
#  (4,
#   {0: {'weight': 3770},
#    1: {'weight': 3770},
#    2: {'weight': 3596},
#    3: {'weight': 3773},
#    5: {'weight': 3770},
#    6: {'weight': 3582},
#    7: {'weight': 3597},
#    8: {'weight': 3596},
#    9: {'weight': 3596},
#    10: {'weight': 3596},
#    11: {'weight': 3596},
#    12: {'weight': 3596},
#    13: {'weight': 3082},
#    14: {'weight': 2115},
#    15: {'weight': 3766},
#    16: {'weight': 3769},
#    17: {'weight': 3613},
#    18: {'weight': 3611},
#    19: {'weight': 3625}}),
#  (5,
#   {0: {'weight': 4687},
#    8: {'weight': 4249},
#    9: {'weight': 4249},
#    10: {'weight': 4249},
#    11: {'weight': 4249},
#    12: {'weight': 4249},
#    13: {'weight': 3734},
#    14: {'weight': 2651},
#    15: {'weight': 4496},
#    17: {'weight': 4284},
#    18: {'weight': 4275},
#    19: {'weight': 4301}}),
#  (17,
#   {0: {'weight': 4279},
#    1: {'weight': 4277},
#    2: {'weight': 4249},
#    3: {'weight': 4277},
#    4: {'weight': 3613},
#    5: {'weight': 4279},
#    6: {'weight': 4221},
#    7: {'weight': 4249},
#    8: {'weight': 4249},
#    9: {'weight': 4249},
#    10: {'weight': 4249},
#    11: {'weight': 4249},
#    12: {'weight': 4249},
#    13: {'weight': 3545},
#    14: {'weight': 2547},
#    15: {'weight': 4278},
#    16: {'weight': 4284},
#    18: {'weight': 4275},
#    19: {'weight': 4090}}),
#  (18,
#   {0: {'weight': 4275},
#    1: {'weight': 4275},
#    2: {'weight': 4249},
#    3: {'weight': 4275},
#    4: {'weight': 3611},
#    5: {'weight': 4275},
#    6: {'weight': 4218},
#    7: {'weight': 4249},
#    8: {'weight': 4249},
#    9: {'weight': 4249},
#    10: {'weight': 4249},
#    11: {'weight': 4249},
#    12: {'weight': 4249},
#    13: {'weight': 3545},
#    14: {'weight': 2547},
#    15: {'weight': 4275},
#    16: {'weight': 4275},
#    17: {'weight': 4275},
#    19: {'weight': 4088}}),
#  (19,
#   {0: {'weight': 4301},
#    1: {'weight': 4304},
#    2: {'weight': 4062},
#    3: {'weight': 4301},
#    4: {'weight': 3625},
#    5: {'weight': 4301},
#    6: {'weight': 4034},
#    7: {'weight': 4067},
#    8: {'weight': 4064},
#    9: {'weight': 4062},
#    10: {'weight': 4062},
#    11: {'weight': 4062},
#    12: {'weight': 4062},
#    13: {'weight': 3646},
#    14: {'weight': 2614},
#    15: {'weight': 4301},
#    16: {'weight': 4301},
#    17: {'weight': 4090},
#    18: {'weight': 4088}})]

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
from matplotlib import rc
import networkx as nx

font_name = 'Gulim'
print(font_name)
plt.rc('font', family=font_name)

fig = plt.figure()
fig.set_size_inches(30, 30)
ax = fig.add_subplot(1, 1, 1)
ax.axis("off")
option = {
    'node_color' : 'lightpink',
    'node_size' : 2000,
    'font_family': font_name,
    'font_size' : 40,
    'font_color' : 'black'
}

plt.title('Random Layout', fontsize=20)
nx.draw(minwon_network,labels=minwon_id2word, ax = ax, **option)
# Out:
# Gulim

# %%
fig = plt.figure()
fig.set_size_inches(20, 20)
option = {
    'node_color' : 'purple',
    'node_size' : 500
}

plt.subplot(221)
plt.title('Random Layout', fontsize=20)
nx.draw_random(minwon_network,labels=minwon_id2word, font_family=font_name, **option)
plt.subplot(222)
plt.title('Circular Layout', fontsize=20)
nx.draw_circular(minwon_network,labels=minwon_id2word, font_family=font_name, **option)
plt.subplot(223)
plt.title('Spectral Layout',fontsize=20)
nx.draw_spectral(minwon_network,labels=minwon_id2word, font_family=font_name, **option)
plt.subplot(224)
plt.title('Spring Layout',fontsize=20)
nx.draw_spring(minwon_network,labels=minwon_id2word, font_family=font_name, **option)
